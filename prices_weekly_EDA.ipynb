# %%
import pandas as pd

xls = pd.ExcelFile('companies_weekly.xlsx')
sheets = xls.sheet_names
sheet_to_df_map = {}
for sheet in sheets:
    sheet_to_df_map[sheet] = xls.parse(sheet)

# %%
df = pd.concat(sheet_to_df_map.values(), ignore_index=True)

# %%
df
# Out:
#          COMP  #N/A                    Date   Open   High    Low  Close  \
# 0     ALLIANZ   NaN                     NaT    NaN    NaN    NaN    NaN
# 1     ALLIANZ   NaN                     NaT    NaN    NaN    NaN    NaN
# 2     ALLIANZ   NaN                     NaT    NaN    NaN    NaN    NaN
# 3     ALLIANZ   NaN                     NaT    NaN    NaN    NaN    NaN
# 4     ALLIANZ   NaN                     NaT    NaN    NaN    NaN    NaN
# ...       ...   ...                     ...    ...    ...    ...    ...
# 3501  ZALANDO   NaN 2023-07-14 17:30:00.288  24.58  29.37  24.19  28.21
# 3502  ZALANDO   NaN 2023-07-21 17:30:00.288  27.92  31.10  27.43  31.01
# 3503  ZALANDO   NaN 2023-07-28 17:30:00.288  30.75  32.17  30.28  31.29
# 3504  ZALANDO   NaN 2023-08-04 17:30:00.288  31.21  32.00  28.86  30.88
# 3505  ZALANDO   NaN 2023-08-10 17:30:00.288  30.61  31.39  28.40  29.38
#
#          Volume
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 3501  6757448.0
# 3502  5891473.0
# 3503  4754685.0
# 3504  5560874.0
# 3505  3587170.0
#
# [3506 rows x 8 columns]

# %%
ALV = df[df["COMP"]=="ALLIANZ"]

# %%
ALV
# Out:
#         COMP  #N/A Date  Open  High  Low  Close  Volume
# 0    ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
# 1    ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
# 2    ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
# 3    ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
# 4    ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
# ..       ...   ...  ...   ...   ...  ...    ...     ...
# 229  ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
# 230  ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
# 231  ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
# 232  ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
# 233  ALLIANZ   NaN  NaT   NaN   NaN  NaN    NaN     NaN
#
# [234 rows x 8 columns]

# %%
BAS = df[df["COMP"]=="BASF"]

# %%
BAS
# Out:
#      COMP  #N/A                    Date  Open  High   Low  Close      Volume
# 234  BASF   NaN 2019-03-01 16:00:00.288  2.74  2.74  2.74   2.74   1979005.0
# 235  BASF   NaN 2019-03-08 16:00:00.288  2.74  2.74  2.74   2.74   4328933.0
# 236  BASF   NaN 2019-03-15 16:00:00.288  2.74  3.20  1.83   2.74  30409823.0
# 237  BASF   NaN 2019-03-22 16:00:00.288  2.74  2.74  2.74   2.74  11411394.0
# 238  BASF   NaN 2019-03-29 16:00:00.288  2.74  3.66  2.74   2.74  23010566.0
# ..    ...   ...                     ...   ...   ...   ...    ...         ...
# 460  BASF   NaN 2023-07-14 16:00:00.288  0.11  0.14  0.11   0.12   5174972.0
# 461  BASF   NaN 2023-07-21 16:00:00.288  0.12  0.12  0.10   0.10   2933379.0
# 462  BASF   NaN 2023-07-28 16:00:00.288  0.10  0.12  0.10   0.11   1717913.0
# 463  BASF   NaN 2023-08-04 16:00:00.288  0.11  0.12  0.10   0.11    907515.0
# 464  BASF   NaN 2023-08-10 16:00:00.288  0.11  0.12  0.10   0.11   1284244.0
#
# [231 rows x 8 columns]

# %%
BMW = df[df["COMP"]=="BMW"]

# %%
BMW
# Out:
#     COMP  #N/A                    Date    Open    High     Low   Close  \
# 465  BMW   NaN 2019-02-22 17:30:00.288   70.20   73.75   69.96   73.13
# 466  BMW   NaN 2019-03-01 17:30:00.288   73.79   75.54   72.91   74.75
# 467  BMW   NaN 2019-03-08 17:30:00.288   75.33   75.40   71.41   72.16
# 468  BMW   NaN 2019-03-15 17:30:00.288   72.25   75.18   71.92   74.09
# 469  BMW   NaN 2019-03-22 17:30:00.288   74.30   76.50   69.18   69.60
# ..   ...   ...                     ...     ...     ...     ...     ...
# 694  BMW   NaN 2023-07-14 17:30:00.288  106.98  108.82  105.16  106.76
# 695  BMW   NaN 2023-07-21 17:30:00.288  106.40  108.76  106.10  107.58
# 696  BMW   NaN 2023-07-28 17:30:00.288  107.34  111.56  105.82  111.28
# 697  BMW   NaN 2023-08-04 17:30:00.288  111.34  111.76  101.98  104.08
# 698  BMW   NaN 2023-08-10 17:30:00.288  103.90  104.76  101.14  101.90
#
#          Volume
# 465   7245586.0
# 466   6958915.0
# 467   7051548.0
# 468   9391529.0
# 469  11942632.0
# ..          ...
# 694   3911936.0
# 695   3515199.0
# 696   4157661.0
# 697   7029601.0
# 698   3113953.0
#
# [234 rows x 8 columns]

# %%
DHER = df[df["COMP"]=="DELIVERY HERO"]

# %%
DHER
# Out:
#               COMP  #N/A                    Date   Open   High    Low  Close  \
# 699  DELIVERY HERO   NaN 2019-02-22 17:30:00.288  35.98  36.20  33.32  33.58
# 700  DELIVERY HERO   NaN 2019-03-01 17:30:00.288  34.00  34.98  33.28  34.70
# 701  DELIVERY HERO   NaN 2019-03-08 17:30:00.288  34.98  35.78  34.50  35.50
# 702  DELIVERY HERO   NaN 2019-03-15 17:30:00.288  35.50  35.90  34.88  35.50
# 703  DELIVERY HERO   NaN 2019-03-22 17:30:00.288  35.74  35.80  34.66  34.66
# ..             ...   ...                     ...    ...    ...    ...    ...
# 928  DELIVERY HERO   NaN 2023-07-14 17:30:00.288  39.10  42.96  38.71  41.34
# 929  DELIVERY HERO   NaN 2023-07-21 17:30:00.288  40.55  42.81  39.30  40.94
# 930  DELIVERY HERO   NaN 2023-07-28 17:30:00.288  40.67  41.43  38.65  40.92
# 931  DELIVERY HERO   NaN 2023-08-04 17:30:00.288  40.62  41.54  36.86  38.40
# 932  DELIVERY HERO   NaN 2023-08-10 17:30:00.288  38.13  41.17  36.74  39.62
#
#         Volume
# 699  1980308.0
# 700  1562496.0
# 701  1312130.0
# 702  2196327.0
# 703  1333578.0
# ..         ...
# 928  2579640.0
# 929  2448001.0
# 930  2311234.0
# 931  2297369.0
# 932  2121944.0
#
# [234 rows x 8 columns]

# %%
DBK = df[df["COMP"]=="DEUTSCHEBANK"]

# %%
DBK
# Out:
#               COMP  #N/A                    Date   Open   High    Low  Close  \
# 933   DEUTSCHEBANK   NaN 2019-02-22 17:30:00.288   7.70   7.80   7.41   7.62
# 934   DEUTSCHEBANK   NaN 2019-03-01 17:30:00.288   7.68   8.30   7.57   8.17
# 935   DEUTSCHEBANK   NaN 2019-03-08 17:30:00.288   8.24   8.28   7.60   7.68
# 936   DEUTSCHEBANK   NaN 2019-03-15 17:30:00.288   7.71   8.21   7.65   7.82
# 937   DEUTSCHEBANK   NaN 2019-03-22 17:30:00.288   8.00   8.23   7.26   7.28
# ...            ...   ...                     ...    ...    ...    ...    ...
# 1162  DEUTSCHEBANK   NaN 2023-07-14 17:30:00.288   9.25   9.88   9.23   9.61
# 1163  DEUTSCHEBANK   NaN 2023-07-21 17:30:00.288   9.57  10.26   9.55  10.20
# 1164  DEUTSCHEBANK   NaN 2023-07-28 17:30:00.288  10.16  10.71  10.06  10.11
# 1165  DEUTSCHEBANK   NaN 2023-08-04 17:30:00.288  10.15  10.18   9.74  10.06
# 1166  DEUTSCHEBANK   NaN 2023-08-10 17:30:00.288  10.04  10.14   9.64  10.01
#
#           Volume
# 933   46265221.0
# 934   64042098.0
# 935   64444070.0
# 936   76246806.0
# 937   90066756.0
# ...          ...
# 1162  55915824.0
# 1163  57275359.0
# 1164  72575114.0
# 1165  42311725.0
# 1166  36394405.0
#
# [234 rows x 8 columns]

# %%
DTE = df[df["COMP"]=="DEUTSCHE TELEKOM"]

# %%
DTE
# Out:
#                   COMP  #N/A                    Date    Open    High     Low  \
# 1167  DEUTSCHE TELEKOM   NaN 2019-02-22 16:00:00.288  101.92  105.34  101.41
# 1168  DEUTSCHE TELEKOM   NaN 2019-03-01 16:00:00.288  105.30  105.37  103.39
# 1169  DEUTSCHE TELEKOM   NaN 2019-03-08 16:00:00.288  104.77  105.09  103.82
# 1170  DEUTSCHE TELEKOM   NaN 2019-03-15 16:00:00.288  104.83  106.20  104.51
# 1171  DEUTSCHE TELEKOM   NaN 2019-03-22 16:00:00.288  105.51  106.95  103.56
# ...                ...   ...                     ...     ...     ...     ...
# 1396  DEUTSCHE TELEKOM   NaN 2023-07-14 16:00:00.288  109.66  113.44  108.25
# 1397  DEUTSCHE TELEKOM   NaN 2023-07-21 16:00:00.288  112.94  115.42  108.66
# 1398  DEUTSCHE TELEKOM   NaN 2023-07-28 16:00:00.288  115.21  116.73  113.04
# 1399  DEUTSCHE TELEKOM   NaN 2023-08-04 16:00:00.288  114.01  114.95  107.14
# 1400  DEUTSCHE TELEKOM   NaN 2023-08-10 16:00:00.288  108.57  109.50  106.81
#
#        Close     Volume
# 1167  105.27  5130019.0
# 1168  104.57  5326761.0
# 1169  104.82  5090356.0
# 1170  105.49  7819359.0
# 1171  106.26  7459816.0
# ...      ...        ...
# 1396  112.95  4697640.0
# 1397  115.12  4600392.0
# 1398  113.57  4789220.0
# 1399  107.88  5956204.0
# 1400  107.28  4134509.0
#
# [234 rows x 8 columns]

# %%
HFG = df[df["COMP"]=="HELLOFRESH"]

# %%
HFG
# Out:
#             COMP  #N/A                Date   Open   High    Low  Close  \
# 1401  HELLOFRESH   NaN 2019-02-22 16:30:00  908.0  948.0  900.0  924.0
# 1402  HELLOFRESH   NaN 2019-03-01 16:30:00  938.0  940.0  896.0  934.0
# 1403  HELLOFRESH   NaN 2019-03-08 16:30:00  938.0  938.0  904.0  916.0
# 1404  HELLOFRESH   NaN 2019-03-15 16:30:00  922.0  950.0  900.0  934.0
# 1405  HELLOFRESH   NaN 2019-03-22 16:30:00  910.0  958.0  910.0  924.0
# ...          ...   ...                 ...    ...    ...    ...    ...
# 1630  HELLOFRESH   NaN 2023-07-14 16:30:00  631.0  678.0  631.0  650.0
# 1631  HELLOFRESH   NaN 2023-07-21 16:30:00  655.0  670.0  633.0  658.0
# 1632  HELLOFRESH   NaN 2023-07-28 16:30:00  656.0  666.0  630.0  648.0
# 1633  HELLOFRESH   NaN 2023-08-04 16:30:00  646.0  675.0  632.0  669.0
# 1634  HELLOFRESH   NaN 2023-08-09 16:30:00  663.0  717.0  659.6  704.0
#
#         Volume
# 1401  359869.0
# 1402  106313.0
# 1403  121042.0
# 1404  307495.0
# 1405   86124.0
# ...        ...
# 1630  322486.0
# 1631  520507.0
# 1632  459248.0
# 1633  352785.0
# 1634  640115.0
#
# [234 rows x 8 columns]

# %%
HEN = df[df["COMP"]=="HENKEL"]

# %%
HEN
# Out:
#         COMP  #N/A                    Date   Open   High    Low  Close  \
# 1635  HENKEL   NaN 2019-02-22 17:30:00.288  81.05  83.60  80.85  82.50
# 1636  HENKEL   NaN 2019-03-01 17:30:00.288  82.95  84.15  81.15  83.35
# 1637  HENKEL   NaN 2019-03-08 17:30:00.288  83.95  84.20  82.60  82.95
# 1638  HENKEL   NaN 2019-03-15 17:30:00.288  82.90  84.65  81.90  84.05
# 1639  HENKEL   NaN 2019-03-22 17:30:00.288  84.45  84.45  81.55  82.20
# ...      ...   ...                     ...    ...    ...    ...    ...
# 1864  HENKEL   NaN 2023-07-14 17:30:00.288  61.74  63.52  61.56  63.32
# 1865  HENKEL   NaN 2023-07-21 17:30:00.288  63.34  64.06  62.54  63.86
# 1866  HENKEL   NaN 2023-07-28 17:30:00.288  63.50  64.62  62.78  64.20
# 1867  HENKEL   NaN 2023-08-04 17:30:00.288  64.48  64.48  61.58  62.02
# 1868  HENKEL   NaN 2023-08-10 17:30:00.288  62.00  63.98  61.60  63.44
#
#         Volume
# 1635  517616.0
# 1636  581261.0
# 1637  388318.0
# 1638  365333.0
# 1639  335472.0
# ...        ...
# 1864  244606.0
# 1865  249429.0
# 1866  301095.0
# 1867  315922.0
# 1868  211591.0
#
# [234 rows x 8 columns]

# %%
BOSS = df[df["COMP"]=="HUGO BOSS"]

# %%
BOSS
# Out:
#            COMP  #N/A                    Date   Open   High    Low  Close  \
# 1869  HUGO BOSS   NaN 2019-02-22 16:00:00.288  19.55  19.66  19.35  19.65
# 1870  HUGO BOSS   NaN 2019-03-01 16:00:00.288  19.86  19.91  19.67  19.85
# 1871  HUGO BOSS   NaN 2019-03-08 16:00:00.288  19.74  19.74  18.99  19.10
# 1872  HUGO BOSS   NaN 2019-03-15 16:00:00.288  19.45  19.80  19.42  19.71
# 1873  HUGO BOSS   NaN 2019-03-22 16:00:00.288  19.82  20.15  19.59  19.59
# ...         ...   ...                     ...    ...    ...    ...    ...
# 2098  HUGO BOSS   NaN 2023-07-14 16:00:00.288  27.11  28.49  27.08  28.16
# 2099  HUGO BOSS   NaN 2023-07-21 16:00:00.288  28.51  28.91  28.21  28.21
# 2100  HUGO BOSS   NaN 2023-07-28 16:00:00.288  28.13  28.53  27.80  28.52
# 2101  HUGO BOSS   NaN 2023-08-04 16:00:00.288  28.93  28.94  27.58  27.58
# 2102  HUGO BOSS   NaN 2023-08-10 16:00:00.288  27.50  27.66  26.81  26.91
#
#        Volume
# 1869   8902.0
# 1870   6703.0
# 1871   5637.0
# 1872  10430.0
# 1873  11731.0
# ...       ...
# 2098  12319.0
# 2099   3711.0
# 2100   7599.0
# 2101   4296.0
# 2102   1822.0
#
# [234 rows x 8 columns]

# %%
LHA = df[df["COMP"]=="LUFTHANSA"]

# %%
LHA
# Out:
#            COMP  #N/A                    Date   Open   High    Low  Close  \
# 2103  LUFTHANSA   NaN 2019-02-22 17:30:00.288  15.99  16.73  15.62  16.67
# 2104  LUFTHANSA   NaN 2019-03-01 17:30:00.288  16.75  16.89  15.82  16.40
# 2105  LUFTHANSA   NaN 2019-03-08 17:30:00.288  16.42  16.53  15.68  15.80
# 2106  LUFTHANSA   NaN 2019-03-15 17:30:00.288  16.08  16.34  15.06  15.08
# 2107  LUFTHANSA   NaN 2019-03-22 17:30:00.288  15.13  15.14  13.94  14.03
# ...         ...   ...                     ...    ...    ...    ...    ...
# 2332  LUFTHANSA   NaN 2023-07-14 17:30:00.288   8.99   9.19   8.72   8.79
# 2333  LUFTHANSA   NaN 2023-07-21 17:30:00.288   8.75   8.93   8.61   8.85
# 2334  LUFTHANSA   NaN 2023-07-28 17:30:00.288   8.73   9.11   8.65   9.03
# 2335  LUFTHANSA   NaN 2023-08-04 17:30:00.288   9.07   9.25   8.18   8.57
# 2336  LUFTHANSA   NaN 2023-08-10 17:30:00.288   8.54   8.88   8.51   8.80
#
#           Volume
# 2103  16351489.0
# 2104  18541946.0
# 2105  17052912.0
# 2106  30007081.0
# 2107  23645478.0
# ...          ...
# 2332  21124849.0
# 2333  16177351.0
# 2334  18428449.0
# 2335  44596735.0
# 2336  14956269.0
#
# [234 rows x 8 columns]

# %%
SAP = df[df["COMP"]=="SAP"]

# %%
SAP
# Out:
#      COMP  #N/A                    Date    Open    High     Low   Close  \
# 2337  SAP   NaN 2019-02-22 16:00:00.288  106.06  108.48  106.06  108.32
# 2338  SAP   NaN 2019-03-01 16:00:00.288  107.72  108.58  106.24  108.38
# 2339  SAP   NaN 2019-03-08 16:00:00.288  108.00  108.28  106.11  107.97
# 2340  SAP   NaN 2019-03-15 16:00:00.288  106.66  112.77  106.66  112.49
# 2341  SAP   NaN 2019-03-22 16:00:00.288  111.99  114.91  111.09  111.72
# ...   ...   ...                     ...     ...     ...     ...     ...
# 2566  SAP   NaN 2023-07-14 16:00:00.288  133.39  144.90  133.37  144.35
# 2567  SAP   NaN 2023-07-21 16:00:00.288  142.86  145.10  133.04  134.02
# 2568  SAP   NaN 2023-07-28 16:00:00.288  133.52  136.84  131.11  136.81
# 2569  SAP   NaN 2023-08-04 16:00:00.288  137.27  137.70  131.91  132.96
# 2570  SAP   NaN 2023-08-10 16:00:00.288  135.52  139.51  133.18  137.89
#
#          Volume
# 2337  1658724.0
# 2338  2223541.0
# 2339  1787396.0
# 2340  2521943.0
# 2341  2780305.0
# ...         ...
# 2566  6045794.0
# 2567  7871813.0
# 2568  4867016.0
# 2569  3574299.0
# 2570  4438537.0
#
# [234 rows x 8 columns]

# %%
SIE = df[df["COMP"]=="SIEMENS"]

# %%
SIE
# Out:
#          COMP  #N/A                    Date  Open  High   Low  Close  \
# 2571  SIEMENS   NaN 2019-02-22 16:00:00.288  0.05  0.05  0.05   0.05
# 2572  SIEMENS   NaN 2019-03-01 16:00:00.288  0.05  0.05  0.05   0.05
# 2573  SIEMENS   NaN 2019-03-06 16:00:00.288  0.05  0.05  0.05   0.05
# 2574  SIEMENS   NaN 2019-03-15 16:00:00.288  0.05  0.05  0.05   0.05
# 2575  SIEMENS   NaN 2019-03-22 16:00:00.288  0.05  0.05  0.04   0.05
# ...       ...   ...                     ...   ...   ...   ...    ...
# 2799  SIEMENS   NaN 2023-07-14 16:00:00.288  0.05  0.05  0.04   0.05
# 2800  SIEMENS   NaN 2023-07-21 16:00:00.288  0.05  0.05  0.04   0.05
# 2801  SIEMENS   NaN 2023-07-27 16:00:00.288  0.05  0.05  0.05   0.05
# 2802  SIEMENS   NaN 2023-08-04 16:00:00.288  0.05  0.05  0.04   0.04
# 2803  SIEMENS   NaN 2023-08-09 16:00:00.288  0.04  0.04  0.04   0.04
#
#          Volume
# 2571   714300.0
# 2572   454000.0
# 2573    61160.0
# 2574   458000.0
# 2575   467000.0
# ...         ...
# 2799  1405000.0
# 2800   432500.0
# 2801   419520.0
# 2802   897000.0
# 2803   680000.0
#
# [233 rows x 8 columns]

# %%
UNA = df[df["COMP"]=="UNILEVER"]

# %%
UNA
# Out:
#           COMP  #N/A                    Date   Open   High    Low  Close  \
# 2804  UNILEVER   NaN 2019-02-22 17:39:59.904  48.82  49.77  48.40  48.78
# 2805  UNILEVER   NaN 2019-03-01 17:39:59.904  48.94  49.08  46.92  47.05
# 2806  UNILEVER   NaN 2019-03-08 17:39:59.904  47.27  49.03  46.96  48.73
# 2807  UNILEVER   NaN 2019-03-15 17:39:59.904  48.90  50.69  47.77  50.51
# 2808  UNILEVER   NaN 2019-03-22 17:39:59.904  50.73  51.37  50.30  51.08
# ...        ...   ...                     ...    ...    ...    ...    ...
# 3033  UNILEVER   NaN 2023-07-14 17:39:59.904  46.64  46.81  46.33  46.59
# 3034  UNILEVER   NaN 2023-07-21 17:39:59.904  46.61  47.34  46.28  47.15
# 3035  UNILEVER   NaN 2023-07-28 17:39:59.904  47.02  49.50  46.03  49.24
# 3036  UNILEVER   NaN 2023-08-04 17:39:59.904  49.30  49.30  47.26  47.34
# 3037  UNILEVER   NaN 2023-08-10 17:39:59.904  47.26  47.89  47.04  47.82
#
#           Volume
# 2804  13224148.0
# 2805  22121205.0
# 2806  17948268.0
# 2807  27468423.0
# 2808  17606605.0
# ...          ...
# 3033   5572649.0
# 3034   6035515.0
# 3035   8530198.0
# 3036   6257332.0
# 3037   4278778.0
#
# [234 rows x 8 columns]

# %%
VOW3 = df[df["COMP"]=="VOLKSWAGEN"]

# %%
VOW3
# Out:
#             COMP  #N/A                    Date    Open    High     Low  \
# 3038  VOLKSWAGEN   NaN 2019-02-22 17:30:00.288  143.08  149.44  140.82
# 3039  VOLKSWAGEN   NaN 2019-03-01 17:30:00.288  148.20  154.94  147.48
# 3040  VOLKSWAGEN   NaN 2019-03-08 17:30:00.288  154.56  155.42  145.36
# 3041  VOLKSWAGEN   NaN 2019-03-15 17:30:00.288  147.34  147.74  142.52
# 3042  VOLKSWAGEN   NaN 2019-03-22 17:30:00.288  144.00  149.32  139.14
# ...          ...   ...                     ...     ...     ...     ...
# 3267  VOLKSWAGEN   NaN 2023-07-14 17:30:00.288  122.16  124.88  120.26
# 3268  VOLKSWAGEN   NaN 2023-07-21 17:30:00.288  122.44  125.10  121.52
# 3269  VOLKSWAGEN   NaN 2023-07-28 17:30:00.288  124.62  126.24  118.10
# 3270  VOLKSWAGEN   NaN 2023-08-04 17:30:00.288  121.26  121.84  117.40
# 3271  VOLKSWAGEN   NaN 2023-08-10 17:30:00.288  118.32  118.98  115.22
#
#        Close     Volume
# 3038  146.72  5310475.0
# 3039  154.18  5817393.0
# 3040  147.06  5069609.0
# 3041  144.32  7091496.0
# 3042  139.14  7193642.0
# ...      ...        ...
# 3267  123.16  3481406.0
# 3268  124.92  3261526.0
# 3269  121.28  7289275.0
# 3270  118.58  4792033.0
# 3271  117.68  3757619.0
#
# [234 rows x 8 columns]

# %%
ZAL = df[df["COMP"]=="ZALANDO"]

# %%
ZAL
# Out:
#          COMP  #N/A                    Date   Open   High    Low  Close  \
# 3272  ZALANDO   NaN 2019-02-22 17:30:00.288  26.02  27.26  25.78  26.18
# 3273  ZALANDO   NaN 2019-03-01 17:30:00.288  26.30  32.86  25.89  32.75
# 3274  ZALANDO   NaN 2019-03-08 17:30:00.288  32.75  34.35  31.66  32.81
# 3275  ZALANDO   NaN 2019-03-15 17:30:00.288  32.90  35.38  32.54  35.00
# 3276  ZALANDO   NaN 2019-03-22 17:30:00.288  34.66  35.75  33.78  34.21
# ...       ...   ...                     ...    ...    ...    ...    ...
# 3501  ZALANDO   NaN 2023-07-14 17:30:00.288  24.58  29.37  24.19  28.21
# 3502  ZALANDO   NaN 2023-07-21 17:30:00.288  27.92  31.10  27.43  31.01
# 3503  ZALANDO   NaN 2023-07-28 17:30:00.288  30.75  32.17  30.28  31.29
# 3504  ZALANDO   NaN 2023-08-04 17:30:00.288  31.21  32.00  28.86  30.88
# 3505  ZALANDO   NaN 2023-08-10 17:30:00.288  30.61  31.39  28.40  29.38
#
#          Volume
# 3272  2248685.0
# 3273  7523877.0
# 3274  4350583.0
# 3275  3532341.0
# 3276  2828183.0
# ...         ...
# 3501  6757448.0
# 3502  5891473.0
# 3503  4754685.0
# 3504  5560874.0
# 3505  3587170.0
#
# [234 rows x 8 columns]

# %%
# GRAPHS

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
VOW3 = df[df['COMP'] == 'VOLKSWAGEN']

VOW3['Date'] = VOW3['Date'].astype('datetime64[ns]')



plt.figure(figsize=(10, 6))
sns.set_palette('Set2')
sns.lineplot(x= "Date", y = "Open",data = VOW3, label = 'Open')
sns.lineplot(x= "Date", y = "Close",data = VOW3, label = 'Close')
plt.title('VOLKSWAGEN: Opening and Closing Prices')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.legend
plt.show()

# %%
LHA = df[df['COMP'] == 'LUFTHANSA']

LHA['Date'] = LHA['Date'].astype('datetime64[ns]')



plt.figure(figsize=(10, 6))
sns.set_palette('Set2')
sns.lineplot(x= "Date", y = "Open",data = LHA, label = 'Open')
sns.lineplot(x= "Date", y = "Close",data = LHA, label = 'Close')
plt.title('LUFTHANSA: Opening and Closing Prices')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.legend
plt.show()

# %%
DBK = df[df['COMP'] == 'DEUTSCHEBANK']

DBK['Date'] = DBK['Date'].astype('datetime64[ns]')



plt.figure(figsize=(10, 6))
sns.set_palette('Set2')
sns.lineplot(x= "Date", y = "Open",data = DBK, label = 'Open')
sns.lineplot(x= "Date", y = "Close",data = DBK, label = 'Close')
plt.title('DEUTSCHEBANK: Opening and Closing Prices')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.legend
plt.show()
